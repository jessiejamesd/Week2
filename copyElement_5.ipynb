# %%
""" program to copy element 44 and 55 from the following tuple
into a new tuple """
tuple1 = (11, 22, 33, 44, 55, 66)
val1 = tuple1[3]
val2 = tuple1[4]
list1 = [val1, val2]
copied_tuple = tuple(list1)
print(copied_tuple)
# Out:
# (44, 55)
