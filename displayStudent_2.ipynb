# %%
""" Program to accept the details of a student like name, roll
number and mark and display it """
name = input("Enter your Name:")
roll_no = input("Enter your Roll No:")
mark = input("Enter your Mark:")
print("Name:",name,"\nRoll No:",roll_no,"\nMark:",mark)
# Out:
# Enter your Name:Anisha
# Enter your Roll No:21
# Enter your Mark:78
# Name: Anisha
# Roll No: 21
# Mark: 78
