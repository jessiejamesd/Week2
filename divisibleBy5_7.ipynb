# %%
""" program to print only those numbers which are divisible of 5 """
sample_output = []
sample_input = [10, 20,33,46,55]
for x in sample_input: 
  if(x%5==0):    
    sample_output.append(x)
print(sample_output)
# Out:
# [10, 20, 55]
