# %%
""" function called exponent(base,exp) that returns an integer
value of base raises to the power of exp. """
def exponent(base,exp):
  return base**exp
base, exp = input("Enter the base and exponent separated by space").split()
print(base,"raises to the power of",exp,"is",exponent(int(base),int(exp)))
