# %%
"""  program to find the most frequent item in a list of numbers. """
sample = [2, 3, 4, 2, 5, 2]
flag=0
count=0
for x in sample:
  if(sample.count(x)>count):
    flag=x
    count=sample.count(x)
print(flag)
