# %%
""" program to construct the following pattern, using a nested
for loop. """
n=6
for i in range(1,n):
    for j in range(1,i):
        print ('*', end="")
    print("")
   
for i in range(n,1,-1):
    for j in range(i,1,-1):
        print ('*', end="")
    print("")
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *
