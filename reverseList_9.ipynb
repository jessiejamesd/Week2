# %%
""" n program to reverse a list using for loop """
sample_input = [10,40,30,70]
sample_output = []
for x in reversed(range(len(sample_input))):
  sample_output.append(sample_input[x])
print(sample_output)
# Out:
# [70, 30, 40, 10]
