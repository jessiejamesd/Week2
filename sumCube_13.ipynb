# %%
""" function that takes a positive integer and returns the sum of
the cube of all the positive integers smaller than the specified number. """
def sum_cubes(n):
  sum=0
  for x in range(n):
    sum+=x*x*x
  return sum
x = int(input("Enter a positive integer:"))
print("Sum =",sum_cubes(x))
