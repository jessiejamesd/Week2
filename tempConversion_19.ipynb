# %%
""" program to convert temperatures to and from Celsius
Fahrenheit. """
F = int(input("Enter the temperature in Fahrenheit:"))
C = round((5/9)*(F-32))
print("Temperature in Celsius:",C)
F = round((C*(9/5))+32)
print("Temperature in Fahrenheit:",F)
